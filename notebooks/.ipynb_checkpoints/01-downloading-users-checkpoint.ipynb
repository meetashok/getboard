# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
import datetime
import random
import numpy as np

# %%
def build_zipcode(number):
    '''The zip column in the uszips file is read as a number
    This function converts the number to a string and prefixes
    additional zeroes to make the length == 5
    '''
    num_string = str(number)
    if len(num_string) == 5:
        return num_string
    else:
        return (5 - len(num_string))*"0" + num_string
    
def get_zipcodes(filename):
    '''Reads the zipcode file and returns an array of zipcode
    '''
    data = pd.read_csv(filename)
    data["zip"] = data.zip.apply(build_zipcode)
    
    zipcodes = data.zip.values
    
    print(f"Number of zipcodes in US: {len(zipcodes):,.0f}")
    
    return zipcodes

def sleep(MIN_TIME, MAX_TIME):
    time.sleep(random.randint(MIN_TIME*10, MAX_TIME*10)/10)
    
def build_url(zipcode, maxdist):
    base_url = "https://boardgamegeek.com/findgamers.php?action=findclosest&country=US&"
    url = f"{base_url}srczip={zipcode}&maxdist={maxdist}&B1=Submit"
    return url

def get_userinfo(div):
    username = div.get("data-username")
    urlusername = div.get("data-urlusername")
    userid = div.get("data-userid")
    name = div.div.text
    
    return urlusername, username, userid, name

# %%
filename = "../data/uszips.csv"

MIN_TIME = 1
MAX_TIME = 3

MAXDIST = 25

zipcodes = get_zipcodes(filename)
# Out:
# Number of zipcodes in US: 33,099

# %%
n_requests = 0
n_users = 0

for i, zipcode in enumerate(["01451"]):
    url = build_url(zipcode, MAXDIST)
    response = requests.get(url)
    
    timenow = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")
    
    if response.ok:
        html_soup = BeautifulSoup(response.text, 'html.parser')
        user_divs = html_soup.find_all("div", class_="avatarblock")
        with open("../data/usernames_download.csv", "a+") as f:
            record = f"{timenow},{zipcode},{MAXDIST},{len(user_divs)}\n"
            f.write(record)
        if len(user_divs) > 0:
            for div in user_divs:
                urlusername, username, userid, name = get_userinfo(div)
                with open("../data/usernames.csv", "a+") as f:
                    record = f"{zipcode},{MAXDIST},{urlusername},{username},{userid},{name}\n"
                    print(record)
                    f.write(record)
    
    n_requests += 1
    n_users += len(user_divs)
    
    print(f"{timenow}, Requests: {n_requests}, Users: {n_users}")
    
    sleep(MIN_TIME, MAX_TIME)
# Out:
# 01451,25,hacksaw76,Hacksaw76,109835,Andrew Hartland
#
# 01451,25,jwandke,jwandke,17937,Jon
#
# 01451,25,gryphyn,gryphyn,439057,Sarah H
#
# 01451,25,kat1248,kat1248,135709,Ken Taylor
#
# 01451,25,ilikehome,ilikehome,461605,Kevin Oehler
#
# 01451,25,coreyels,CoreyEls,991015,Corey Els
#
# 01451,25,luce,Luce,273710,Reis
#
# 01451,25,noahboa,Noahboa,228910,N S.
#
# 01451,25,jafm,jafm,179521,Joe Medeiros
#
# 01451,25,dcp017,dcp017,1040461,Daniel Prudente
#
# 01451,25,doktortimo,DoktorTimo,1102671,Timothy Estabrooks
#
# 01451,25,kindadistracted,kindadistracted,807510,Becka Dente
#
# 01451,25,craftypenguin,craftypenguin,1161816,Sami D.
#
# 01451,25,joecylon,JoeCylon,1024612,Joe Cylon
#
# 01451,25,abundantchoice,AbundantChoice,208236,Adam B.
#
# 01451,25,m013,M013,1002610,Marc Davis
#
# 01451,25,shingoukufatso,Shingoukufatso,1440139,Dan Castronuova
#
# 01451,25,shiveringjenny,shiveringjenny,1891992,jlf
#
# 01451,25,drdt,drdt,117181,Uncle Don
#
# 01451,25,jagex12,jagex12,514498,Lost Kitsun
#
# 01451,25,caitcreates,caitcreates,1431759,Cait Creates
#
# 01451,25,alex02144,alex02144,558544,Jesse Stern
#
# 01451,25,minh3max,minh3max,1001428,Minh Max
#
# 01451,25,timaxman,timaxman,933846,alex voss
#
# 01451,25,rioniac,rioniac,1217243,Sebastian Courtney
#
# 01451,25,bg-meg,bg_meg,361449,Meg BG
#
# 01451,25,jerilsilver,jerilsilver,1737706,Derrick Smutek
#
# 01451,25,ryha2000,Ryha2000,480242,Christopher Barney
#
# 01451,25,sincere8868,sincere8868,418811,Jeff Gracia
#
# 01451,25,wexia,Wexia,253814,Welch N
#
# 01451,25,theredwagoneer,theredwagoneer,16789,Greg Reimann
#
# 01451,25,masterhalco,MasterHalco,20499,Christopher Plummer
#
# 01451,25,hawkeye-fierce,Hawkeye Fierce,97879,Benjamin Fierce
#
# 01451,25,shankfoo,shankfoo,144001,Kevin Shanahan
#
# 01451,25,thierry-kween,Thierry_kween,1580536,Nicholas Mendoza
#
# 01451,25,rhubahb,rhubahb,402235,Tom Cohen
#
# 01451,25,blurbist,The Blurbist,3900,Chris Lockheardt
#
# 01451,25,wezell,wezell,183127,Will Ezell
#
# 01451,25,gandalf-der-graue,Gandalf_der_Graue,126327,Oliver Purwin
#
# 01451,25,desiderata,Desiderata,185481,Einmal  ist Keinmal
#
# 01451,25,beneaththeearth,BeneathTheEarth,150690,Terry D
#
# 01451,25,doghinp,Doghinp,38315,Clayton Brostowin
#
# 01451,25,dominionfamily,DominionFamily,315580,Marc McConley
#
# 01451,25,bugsaver,bugsaver,667619,Christopher Newman
#
# 01451,25,bosoxbill,bosoxbill,353252,Bill Desmarais
#
# 01451,25,ckaspereli,ckaspereli,6399,chris kasper
#
# 01451,25,hamersong,Hamersong,22274,David Marden
#
# 01451,25,jfaller,jfaller,258562,Jeremy Faller
#
# 01451,25,dkuznick,dkuznick,2092,David Kuznick
#
# 01451,25,dewhite,dewhite,60206,David White
#
# 01451,25,kuragara,kuragara,10799,Frank Tilley
#
# 01451,25,tofugolem,TofuGolem,161077,Kevin Staszowski
#
# 01451,25,psznicx,psznicx,470844,Nicholas Gotch
#
# 01451,25,advanced-ideas,advanced_ideas,38972,Richard Onanian
#
# 01451,25,angelkurisu,angelkurisu,74820,Chris Cieslik
#
# 01451,25,parodielin,parodielin,9285,Kenneth Lin
#
# 01451,25,akatlas,akatlas,1055558,Alia Atlas
#
# 01451,25,modgrrrl,modgrrrl,4180,Martha Barton
#
# 01451,25,chuchu258,chuchu258,488032,Chuchu Train
#
# 01451,25,cromat,Cromat,74083,peter hyde
#
# 01451,25,ijmcf,ijmcf,24175,Iain McFadyen
#
# 01451,25,quincy2112,quincy2112,595601,Quincy Hughes
#
# 01451,25,jdc3164,jdc3164,7067,John Coley
#
# 01451,25,jshuitema,jshuitema,757935,Sigma Filer
#
# 01451,25,thouis,thouis,114363,Thouis Jones
#
# 01451,25,filbert,filbert,21180,Alison Yada
#
# 01451,25,adventure-pub,Adventure_Pub,2012349,Adventure Pub
#
# 01451,25,unit04,Unit04,704446,Peter Tierney
#
# 01451,25,zosa,zosa,11460,Paul Franzosa
#
# 01451,25,crimsonknave,Crimsonknave,487364,Joseph Henrich
#
# 01451,25,yankelburpels,yankelburpels,611270,Jeff Croteau
#
# 01451,25,davewu,davewu,507846,David Wu
#
# 01451,25,colanderman,colanderman,653779,Chris Pacejo
#
# 01451,25,ipreferwalking,ipreferwalking,682465,JM
#
# 01451,25,vwooba,vwooba,314482,John Totten
#
# 01451,25,kyyrr,kyyrr,2571,David S. Lewis
#
# 01451,25,rseater,rseater,102212,Robert Seater
#
# 01451,25,coffeegnerd,CoffeeGnerd,1147580,Shane White
#
# 01451,25,mrsnightskyre,MrsNightskyre,1148563,Anitra Smith
#
# 01451,25,tigerd,TigerD,912795,Tiger Swan
#
# 01451,25,fertilegroundgames,fertilegroundgames,263097,Eric Frederick
#
# 01451,25,gamingcavalry,GamingCavalry,1160377,Saben Schmett
#
# 01451,25,gamefreak22,gamefreak22,30459,Dan Hill
#
# 01451,25,tajones42,tajones42,23478,Tom Jones
#
# 01451,25,elcoderdude,elcoderdude,56952,Robert Ahearne
#
# 01451,25,wsiegel12,wsiegel12,2108354,Bill Siegel
#
# 01451,25,themccubbins,themccubbins,267495,Chris McCubbin
#
# 01451,25,galfridus,galfridus,16973,Geoff Speare
#
# 01451,25,jjrbedford,jjrbedford,33895,Joe J. Rushanan
#
# 01451,25,ddandy,ddandy,6310,David Andrews
#
# 01451,25,mxever7,Mxever7,581081,Glenn B
#
# 01451,25,bloodystar,bloodystar,159214,Salim Mohammed
#
# 01451,25,isthar,isthar,581646,Eddie
#
# 01451,25,nyriv,nyriv,14115,Jeff Fournier
#
# 01451,25,galego,Galego,27896,Thom Goodsell
#
# 01451,25,pherlondeiel,pherlondeiel,86845,Carrie Geldart
#
# 01451,25,absurdknurd,AbsurdKnurd,319069,Dennis Knurd
#
# 01451,25,seandonohue,seandonohue,4241,Sean Donohue
#
# 01451,25,eprebys,eprebys,58059,eric henry
#
# 01451,25,joe-salamone,joe_salamone,230175,Joe Salamone
#
# 01451,25,agiganticpanda,AGiganticPanda,447362,David Overton
#
# 01451,25,karlhanf,karlhanf,50159,Karl Hanf
#
# 01451,25,jpotter,JPotter,981254,Jimmy Potter
#
# 01451,25,jaymoore2000,jaymoore2000,12043,Jay Moore
#
# 01451,25,zodiak-team,Zodiak Team,562468,Dan Lanza
#
# 01451,25,starspangledgirl,starspangledgirl,10025,Carol Carpenter
#
# 01451,25,akeba1,akeba1,238137,Jimmy Elsenbeck
#
# 01451,25,bigdblazin,bigdblazin,1152334,Dave Rini
#
# 01451,25,dewwk,dewwk,493136,Richard Sackett
#
# 01451,25,primerib,PrimeRib,627596,PrimeRib PrimeRib
#
# 01451,25,altoidlover,AltoidLover,66958,Jp LaFond
#
# 01451,25,cvonh,cvonh,2472,Constantine von Hoffman
#
# 01451,25,chronozshre,chronozshre,2201001,Chronoz
#
# 01451,25,dddwwwhhh,dddwwwhhh,8630,D H
#
# 01451,25,tobit-g,Tobit G,796090,Tobit Glenhaber
#
# 01451,25,welsh-druid,Welsh Druid,335296,Jim Dowrey
#
# 01451,25,jtonet,jtonet,176175,Joseph Tonet
#
# 01451,25,twwombat,twwombat,377330,T.W. Wombat
#
# 01451,25,bjh25,bjh25,35115,B Hammond
#
# 01451,25,andrew261,andrew261,701753,Andrew Graham
#
# 01451,25,ohnoitsnathan,ohnoitsnathan,1346141,Nathan Schaaf
#
# 01451,25,boardgame-ben,BoardGame_Ben,467844,Ben Marshalkowski
#
# 01451,25,tyranten,Tyranten,1193949,Jeffrey Zurita
#
# 01451,25,idlerking,idlerking,156671,Will
#
# 01451,25,icarus599,Icarus599,652738,
#
# 01451,25,bbenston,bbenston,38152,Chief Slovenly
#
# 01451,25,devonelle,Devonelle,58889,Jason Quintal
#
# 01451,25,rwodonnell,rwodonnell,243480,Rick O'Donnell
#
# 01451,25,largosama,largosama,8236,Kevin Horwitz
#
# 01451,25,iamthespanky,iamthespanky,298345,Spanky
#
# 01451,25,gleeplewinky,Gleeplewinky,979359,James McIninch
#
# 01451,25,saabpirate,saabpirate,598481,Matt Sperling
#
# 01451,25,explorers-n-builders,explorers-n-builders,10756,Joe Czapski
#
# 01451,25,bmacfarlane,bmacfarlane,262668,Ben MacFarlane
#
# 01451,25,ignignokt,Ignignokt,26393,Jim Kang
#
# 01451,25,dyfrgi,dyfrgi,43810,Michael Leuchtenburg
#
# 01451,25,tetepoov,tetepoov,116258,Douglas Peterson
#
# 01451,25,sdmurphy,sdmurphy,371493,Shawn Murphy
#
# 01451,25,cbudnick,cbudnick,81467,Christopher Budnick
#
# 01451,25,chuck-gamer,chuck_gamer,75867,charles krueger
#
# 01451,25,kubalaa,kubalaa,840825,Adrian Barkuş
#
# 01451,25,ccasin,ccasin,439961,Chris Casinghino
#
# 01451,25,kaitiko,kaitiko,501920,Nicholas Bartoli
#
# 01451,25,gtsazama,gtsazama,332963,Graham Sazama
#
# 01451,25,caitirilt,caitirilt,371161,Jenn C
#
# 01451,25,bigboote,BigBoote,10727,Steve B
#
# 01451,25,grayskale,grayskale,45306,Calm Fluffy Bunnies
#
# 01451,25,atomic-freak,atomic freak,9726,David Glenn
#
# 01451,25,hwango,hwango,166444,Wes Jones
#
# 01451,25,taskboy3000,taskboy3000,946235,Joe Johnston
#
# 01451,25,mikec,mikec,40295,Mike C
#
# 01451,25,petros1976,petros1976,110747,Peter Papadopoulos
#
# 01451,25,jozxyqk,jozxyqk,144600,Joshian Grr
#
# 01451,25,vinniebrasco,vinniebrasco,238842,Vincent White
#
# 01451,25,dpotter2113,dpotter2113,836349,Dustin Potter
#
# 01451,25,gamefundas,gamefundas,228552,Anand Nadar
#
# 01451,25,cfranz,Cfranz,31581,Christopher Rahe
#
# 01451,25,walter47,walter47,2038725,Walter Fortyseven
#
# 01451,25,bzzipper,bzzipper,33886,Andrew Huffman
#
# 01451,25,gm-pax,GM_Pax,913812,Sean Long
#
# 01451,25,hereferfun,HereFerFun,17823,Mark Hauser
#
# 01451,25,pjb51,Pjb51,1083556,Paul B.
#
# 01451,25,labwreck,labwreck,354582,Dan Labrecque
#
# 01451,25,wildpiper,wildpiper,1261374,Pete Schmidt
#
# 01451,25,sharronz,sharronz,22919,Sharron Smith
#
# 01451,25,jsheedy,JSheedy,745881,John Sheedy
#
# 01451,25,skybowl,skybowl,131833,David Smith
#
# 01451,25,dark-son,Dark Son,5639,Keith M. Sandler
#
# 01451,25,vienathedruid,vienathedruid,1451285,Lauren Ignacio
#
# 01451,25,elf-man,Elf__Man,2961,John Elbl
#
# 01451,25,sharoz,sharoz,403371,Sharon R
#
# 01451,25,laurion,laurion,4836,Chad Bergeron
#
# 01451,25,mason000,mason000,33370,Thomas Mason
#
# 01451,25,schneevs67,schneevs67,1133664,Eric Nivala
#
# 01451,25,ctewks,ctewks,294803,Chuck Tewksbury
#
# 01451,25,yahooseriously1,yahooseriously1,742380,Joel Pettit
#
# 01451,25,jarslan,jarslan,98690, Arslanian
#
# 01451,25,glowstickwar,glowstickwar,249655,james carignan
#
# 01451,25,cambridgegames,cambridgegames,71972,Ed Carter
#
# 01451,25,nate-finch,Nate Finch,121241,Nate Finch
#
# 01451,25,skshrews,skshrews,158911,Stephen Kirk
#
# 01451,25,kjell1979,kjell1979,415287,Chuck Knutson
#
# 01451,25,prorock,ProRock,243268,Jason Emerson
#
# 01451,25,adler-hobby,Adler Hobby,162439,Gordon Pittsley
#
# 01451,25,smapdy0,Smapdy0,1486965,Sid Guest
#
# 01451,25,leornere,leornere,651424,Erik Clark
#
# 01451,25,stevec4815,Stevec4815,232482,Steve C.
#
# 01451,25,rentfn,rentfn,623410,Mike Campbell
#
# 01451,25,fermionace,FermionAce,334918,Tom S
#
# 01451,25,ngeunit1,ngeunit1,443246,Dave McAvoy
#
# 01451,25,mpj1,mpj1,64879,Matt J
#
# 01451,25,drasher25,drasher25,20338,Damon Asher
#
# 01451,25,gone,gone,14087,louis mayhew
#
# 01451,25,cean,cean,680997,cean comley
#
# 01451,25,aresangel,aresangel,633966,Tim Vaillancourt
#
# 01451,25,amellors,amellors,25005,Andrew Mellors
#
# 01451,25,kreator82,Kreator82,684210,Shaun Layton
#
# 01451,25,anordinaryhero,Anordinaryhero,1079877,Jason Riddell
#
# 01451,25,thecatguy,TheCatGuy,106844,Paul Rubin
#
# 01451,25,wmshub,wmshub,60576,Billy McBoatface
#
# 01451,25,ashpelon,ashpelon,9890,Matthew Epstein
#
# 01451,25,npattinson,npattinson,766901,Nigel Pattinson
#
# 01451,25,extrospect,extrospect,8632,Mark Andersen
#
# 01451,25,adiamant,adiamant,55524,Asher D.
#
# 01451,25,nberndt,nberndt,310526,Nathan Berndt
#
# 01451,25,rgranville,rgranville,58186,Robert Granville
#
# 01451,25,guinnesspint,GuinnessPint,468565,Matt W
#
# 01451,25,doc-middleton,Doc Middleton,102,Doc Middleton
#
# 01451,25,doughboy42,doughboy42,253441,steve brown
#
# 01451,25,not-jeff,not_jeff,507395,Jeffrey Bourbeau
#
# 01451,25,yakuzaboss,Yakuzaboss,25632,Evan Tannheimer
#
# 01451,25,doink1212,Doink1212,592252,Nick Parenteau
#
# 01451,25,axpbonesaw,axpbonesaw,436668,Dave
#
# 01451,25,roberteno,RobertEno,462,Robert Eno
#
# 01451,25,buckar00,buckar00,310488,Darrick Fauvel
#
# 01451,25,bnolan,bnolan,15237,Brett Nolan
#
# 01451,25,monkeydluffy,MonkeyDLuffy,39092,Matthew LeVan
#
# 01451,25,captainecchi,captainecchi,39400,Lise Fracalossi
#
# 01451,25,juliegbg,JulieGBG,955541,Julie Ahern
#
# 01451,25,lowell888,Lowell888,36264,Mark Lowell
#
# 01451,25,awong,awong,103122,A Wong
#
# 01451,25,sulfurico,Sulfurico,1783309,Fabio Trintinalia
#
# 01451,25,bg816am,bg816am,146731,Brian Gould
#
# 01451,25,dio1632,dio1632,9300,Scott Gray
#
# 01451,25,ludzy,ludzy,911244,Chris Ludlam
#
# 01451,25,starfix,starfix,135628,Star Fix
#
# 01451,25,madmac7287,madmac7287,144095,Mike M.
#
# 01451,25,pikaphanpooh,pikaphanpooh,426756,John Wiley
#
# 01451,25,king-of-battle,king_of_battle,937084,Bryan Herrin
#
# 01451,25,squashrot,SquashRot,900874,Kirk Grentzenberg
#
# 01451,25,klangerdude,klangerdude,1689969,Kenneth P. Langer
#
# 01451,25,excelsiorgames,ExcelsiorGames,1052045,Robert Whitcomb
#
# 01451,25,flyingsheep,FlyingSheep,1518,Chip Beauvais
#
# 01451,25,timpeters,timpeters,66568,Tim Peters
#
# 01451,25,jagophile,jagophile,39463,Adam Foster
#
# 01451,25,jdarnold,jdarnold,811,Jonathan Arnold
#
# 01451,25,marphod,marphod,188205,Galen Brownsmith
#
# 01451,25,parentheticalman,parentheticalman,689974,John M.
#
# 01451,25,locutusmit,LocutusMIT,88142,Charles Leiserson, Jr.
#
# 01451,25,mhoram,mhoram,19039,Mike McLawhorn
#
# 01451,25,tennberg,Tennberg,396397,Michael
#
# 01451,25,tottgwn,tottgwn,353391,Mark Gatesman
#
# 01451,25,steevil,steevil,90234,Stephen Maywalt
#
# 01451,25,cbourassa,cbourassa,19848,Christopher Bourassa
#
# 01451,25,paradoxgraphics,paradoxgraphics,456331,Todd Goodman
#
# 01451,25,oldwindways,oldwindways,101545,Aaron Bell
#
# 01451,25,jmspencer,jmspencer,252844,J. Michael Spencer
#
# 01451,25,casualsax,CasualSax,67004,Michael Berg
#
# 01451,25,bcmcknight77,bcmcknight77,896195,Ben McKnight
#
# 01451,25,applejack1963,applejack1963,211155,Jack Martin
#
# 01451,25,dujo,Dujo,173286,What preview button?
#
# 01451,25,ryan-keane,Ryan Keane,211702,Ryan Keane
#
# 01451,25,gigagamer,gigagamer,231436,Derek Pretti
#
# 01451,25,misterbaldy,misterbaldy,93226,Joseph Geer
#
# 01451,25,marty-s,Marty S,49230,Marty Sample
#
# 01451,25,jdbullock,jdbullock,794970,Jordan Bullock
#
# 01451,25,cck-gnu,cck_gnu,754270,Nate Medsker
#
# 01451,25,rmsarkissian,RMSarkissian,3962,Michael Sarkissian
#
# 01451,25,aunrea,aunrea,97432,Candace Duffy Jones
#
# 01451,25,avid,avid,34490,Scott Jacques
#
# 01451,25,travvller,travvller,357076,Patrick C.
#
# 01451,25,poolyxpop,Poolyxpop,237575,ƒireƒly
#
# 01451,25,atras,Atras,534768,Rob Uccello
#
# 01451,25,robertjanousek,RobertJanousek,65798,Robert Janousek
#
# 01451,25,michaellavoie,MichaelLavoie,246048,Michael Lavoie
#
# 01451,25,dan1066,dan1066,52028,Dan Young
#
# 01451,25,wakko,Wakko,9789,Brett Lentz
#
# 01451,25,shankie,Shankie,442173,Shannon Kane
#
# 01451,25,shadrachanki,ShadrachAnki,453968,Shadrach Anki
#
# 01451,25,jnighthawk,JNighthawk,17242,DJ Hirko
#
# 01451,25,rudmint,Rudmint,271728,Thomas Rudmin
#
# 01451,25,brucekg,brucekg,52595,Bruce Gillespie
#
# 01451,25,porqpine,Porqpine,352127,Ben Coburn
#
# 01451,25,dawnelamb,dawnelamb,127371,Dawne Cox
#
# 01451,25,jforbes,jforbes,229806,Jeff Forbes
#
# 01451,25,paulcolley,paulcolley,2053302,Paul Colley
#
# 01451,25,abyssalstalker,AbyssalStalker,237533,Eric Lustenberger
#
# 01451,25,ncv1901,ncv1901,450528,Nicholas Vaccaro
#
# 01451,25,oonushi,Oonushi,1848562,Michael Kozubal Jr
#
# 01451,25,rickandmark,rickandmark,308354,Marko
#
# 01451,25,mwandjm,mwandjm,362642,Mary McGuire
#
# 01451,25,toyboy101,toyboy101,385204,Peter Belocas
#
# 01451,25,huckleberryfinn,huckleberryfinn,53703,Huckleberry Carignan
#
# 01451,25,gistisgrand,Gistisgrand,780746,
#
# 01451,25,supagerm,SupaGerm,229337,Mick Sullivan
#
# 01451,25,tevacircus,tevacircus,128737,Jeremy Arcus-Goldberg
#
# 01451,25,randiv,randiv,177125,Randal  Divinski
#
# 01451,25,seth2,seth2,262769,Seth B
#
# 01451,25,bgregg,BGregg,382139,B Gregg
#
# 01451,25,richardhmarshall,RichardHMarshall,33326,Richard Marshall
#
# 01451,25,abstractionist,The Abstractionist,240094,Jim "git yer stinkin' themes offa my mechanic" Puccio
#
# 01451,25,amcpherson,amcpherson,117005,Aaron McPherson
#
# 01451,25,confucious,confucious,295704,Jerry Hsu
#
# 01451,25,jacksonmead,jacksonmead,810,Kevin Jackson-Mead
#
# 01451,25,bqfree,bqfree,557633,Barry Freedman
#
# 01451,25,jutetrea,jutetrea,13679,Justin Tetreault
# 01451,25,nomosk,NoMosk,1130363,Noah M
#
# 01451,25,nihryan,nihryan,420222,Ryan Schlimgen
#
# 01451,25,jrice-blue,jrice_blue,749991,Jeremy Rice
#
# 01451,25,gamewrighthq,GamewrightHQ,738235,Gamewright
#
# 01451,25,ndkid,ndkid,56823,Nathan Dilday
#
# 01451,25,p-l-m,P L M,240124,Paul Martenis
#
# 01451,25,lego-army-man,Lego_Army_Man,142760,Evn Tomeny
#
# 01451,25,philbog,philbog,120127,Phil Gross
#
# 01451,25,rukiosu,rukiosu,217360,Sam Yhanto
#
# 01451,25,neoeinstein,neoeinstein,484192,Marcus Griep
#
# 01451,25,animal,animal,1312,Bryan Bowe
#
# 01451,25,aardvarkulator,Aardvarkulator,6844,Pete Bilajung
#
# 01451,25,jlaidler,jlaidler,64542,John Laidler
#
# 01451,25,kristen73,Kristen73,1180530,Kristen Boudreau
#
# 01451,25,bchlax944,bchlax944,429940,Drew Gormley
#
# 01451,25,scottbe,scottbe,37140,Scott Beauregard
#
# 01451,25,enigmakairos,enigmakairos,43559,Melinda Carbonell
#
# 01451,25,uncmike,UncMike,134505,Michael Kagen
#
# 01451,25,jayr13,jayr13,80625,Jason Robbins
#
# 01451,25,cpugs22,cpugs22,28505,Charles Pugsley
#
# 01451,25,vonted,Vonted,3684,
#
# 01451,25,richard220,richard220,474746,Rob Richard
#
# 01451,25,boris317,boris317,159656,Shawn
#
# 01451,25,mathaos42,mathaos42,240055,Matt Pappathan
#
# 01451,25,masaokano,masaokano,1958161,Mas Okano
#
# 01451,25,eyefink,Eyefink,475830,Matthew McFarland
#
# 01451,25,thundergoat,Thundergoat,106446,Joel Carlson
#
# 01451,25,donnaabbott456,donnaabbott456,11745,Donna Abbott
#
# 01451,25,umassice,umassice,10083,Steve Miner
#
# 01451,25,ab5000,ab5000,132367,Andrew Brown
#
# 01451,25,spoonts,spoonts,831,Richard Spoonts
#
# 01451,25,alejand738,Alejand738,1392,Rev. E. Lewis MacLean
#
# 01451,25,pittc,pittc,890,Pitt Crandlemire
#
# 01451,25,sagiro,Sagiro,1406,Dorian Hart
#
# 01451,25,bybluk,bybluk,721050,Dan Liteplo
#
# 01451,25,friedmann207,friedmann207,32966,Andrew Friedmann
#
# 01451,25,mkgray,mkgray,711,Matthew Gray
#
# 01451,25,aarondesk,aarondesk,8711,Garrett the Hammer
#
# 01451,25,merry11,Merry11,27628,Matthew
#
# 01451,25,610jajaja,610jajaja,264454,Rob Killeen
#
# 01451,25,terex,Terex,181085,Adam Reeve
#
# 01451,25,gr8bobo,gr8bobo,1385165,Terry C
#
# 01451,25,dougorleans,DougOrleans,795,Doug Orleans
#
# 01451,25,kaelistus,Kaelistus,3355,Felix Rodriguez
#
# 01451,25,thelastantidote,TheLastAntidote,377643,Matthew Soares
#
# 01451,25,hawkeyeop,hawkeyeop,270646,Joel Fried
#
# 01451,25,lukeweisman,lukeweisman,3907,Luke Weisman
#
# 01451,25,sierrablack,sierrablack,900426,Sierra Black
#
# 01451,25,denniskyc,denniskyc,506963,Dennis Chan
#
# 01451,25,chrisrhoden,chrisrhoden,1002622,Chris Quamme Rhoden
#
# 01451,25,veggeek,veggeek,243347,Arun Sannuti
#
# 01451,25,mimi-says,Mimi Says,1550741,Mimi Says
#
# 01451,25,cambridgegamesartist,cambridgegamesartist,75687,Kris MacCormack
#
# 01451,25,dipmoy,Dipmoy,2200500,Dipmoy Nath
#
# 01451,25,ikn0wyourider,Ikn0wyourider,485827,Chris Danis
#
# 01451,25,rawdealdemo,RawDealDemo,456138,Aaron Bedard
#
# 01451,25,link774,Link774,438239,Brian P
#
# 01451,25,edhart1963,edhart1963,85061,Ed Hart
#
# 01451,25,phunlvr,phunlvr,154139,Wystan Benbow
#
# 01451,25,samtb,samtb,328283,Sam Brelsfoard
#
# 01451,25,elpalchica,elpalchica,152560,Elizabeth Benbow
#
# 01451,25,hnybny,hnybny,49923,Cheryl Wallace
#
# 01451,25,joseanes,joseanes,382732,Jose Anes
#
# 01451,25,jmorgan,jmorgan,51479,John Lione
#
# 01451,25,complex5341,complex5341,78906,Rob Elkind
#
# 01451,25,easilyconfused,EasilyConfused,6334,Daniel Michelson
#
# 01451,25,fueledbykawi,fueledbykawi,1794336,James Florence
#
# 01451,25,enie,enie,573477,enie kamozi
#
# 01451,25,eveator,eveator,502852,Eric
#
# 01451,25,frenchy117,frenchy117,842404,Justin French
#
# 01451,25,geddy19,geddy19,237007,Rich Yasi
#
# 01451,25,downing11,Downing11,1765350,Mike Downing
#
# 01451,25,cradleofmilk,cradleofmilk,50391,michael  dorazio
#
# 01451,25,jeanvabu,jeanvabu,64013,Jennifer van Buren
#
# 01451,25,a-brit-abroad,a_brit_abroad,51216,Ed Carter
#
# 01451,25,jakevarney,jakevarney,47251,jake varney
#
# 01451,25,aamax,aamax,60343,Aaron Maxim
#
# 01451,25,daforsto,daforsto,166725,David Forstot
#
# 01451,25,lyingjerk,lyingjerk,14688,dale henderson
#
# 01451,25,zavesky,zavesky,1998088,Ray Zavesky
#
# 01451,25,lynxreign,LynxReign,22285,Stefan Krzywicki
#
# 01451,25,nmkaplan,nmkaplan,301840,Nathan Kaplan
#
# 01451,25,kellyeverett,kellyeverett,19990,Kelly Durkee-Erwin
#
# 01451,25,dragoon24,Dragoon24,100643,Alexander Shvarts
#
# 01451,25,ronco,Ronco,5671,Dean O'Donnell
#
# 01451,25,bronzite,Bronzite,58919,John Brewer
#
# 01451,25,benj06a,benj06a,362280,Benjamin Piat
#
# 01451,25,trystero11,trystero11,357940,Douglas Bailey
#
# 01451,25,terry-egan,Terry Egan,838,Terry Egan
#
# 01451,25,cschroeder83,cschroeder83,463975,Curt Schroeder
#
# 01451,25,deadly-butler,Deadly_Butler,25744,Bob Swander
#
# 01451,25,notmatthew,notmatthew,432791,matthew Cassidy
#
# 01451,25,jjacy1,jjacy1,38052,J Jacy
#
# 01451,25,doodle,Doodle,62636,Alix/Lex Remes
#
# 01451,25,pierogiboy,pierogiboy,116144,Mark Hickernell
#
# 01451,25,vitas,vitas,3520,Vitas Povilaitis
#
# 01451,25,okiedokieiguess,okiedokieiguess,757963,Derek Stotz
#
# 01451,25,orewashinanai,orewashinanai,206331,Thomas Lee
#
# 01451,25,dlowe,dlowe,409853,Daniel Lowe
#
# 01451,25,mrbranden,mrbranden,744204,Branden L
#
# 01451,25,desonos,Desonos,668180,Jared Rice
#
# 01451,25,gunboat,gunboat,136990,Sam Phinizy
#
# 01451,25,qtan,Qtan,1871183,Wei Luo
#
# 01451,25,dlgross,dlgross,557908,David Gross
#
# 01451,25,falsetto621,falsetto621,588899,Lam Dinh
#
# 01451,25,dasilodavi,dasilodavi,60821,Brandon Rahhal
#
# 01451,25,cmdroverbite,CmdrOverbite,424357,PJ Killian
#
# 01451,25,yendi,yendi,125108,Adam Lipkin
#
# 01451,25,merkin,Merkin,730045,Randy Baril
#
# 01451,25,marktowler,marktowler,43484,Mark Towler
#
# 01451,25,tcauchon,tcauchon,32990,Thomas Cauchon
#
# 01451,25,keyser42soze,keyser42soze,120816,Sam Richardson
#
# 01451,25,adfoland,adfoland,67860,Andrew Foland
#
# 01451,25,askeeve,askeeve,506505,Adam Cooperman
#
# 01451,25,dave-richtmyer,Dave Richtmyer,6710,David Richtmyer
#
# 01451,25,philosopherclown,PhilosopherClown,417116,Michael LaPointe
#
# 01451,25,subcon,Subcon,866947,Avi Chandavarkar
#
# 01451,25,tylik,tylik,636393,Dima Tylik
#
# 01451,25,chkajudo,chkajudo,129796,Don Aiken
#
# 01451,25,k1nu,k1nu,179732,Len K
#
# 01451,25,sushiboy,Sushiboy,311,Deron Dorna
#
# 01451,25,skarsenal,skarsenal,536953,Robert S
#
# 01451,25,swordjockey,swordjockey,353685,Timothy McGee
#
# 01451,25,minifig,Minifig,84162,Suzanne Eaton
#
# 01451,25,rhynonorm,rhynonorm,416724,Norm Vaillancourt
#
# 01451,25,jbluestein,jbluestein,7164,Joshua Bluestein
#
# 01451,25,buadb,buadb,879220,Adam Bryant
#
# 01451,25,neiname,neiname,346483,Chris Koenig
#
# 01451,25,jeremytravis,jeremytravis,1303045,Jeremy Travis
#
# 01451,25,jadthegerbil,JadtheGerbil,201242,Jeremy Tudisco
#
# 01451,25,atm0spherical,atm0spherical,1052450,Dawson Mertz
#
# 01451,25,wwscrispin,wwscrispin,96327,William Crispin
#
# 01451,25,pickew,Pickew,953445,Will Pickering
#
# 01451,25,katespace,katespace,49806,Karen Yurek
#
# 01451,25,hfirimain,hfirimain,63441,jason balinski
#
# 01451,25,erikmallinson,erikmallinson,90985,Erik Mallinson
#
# 01451,25,derekd,DerekD,94102,Derek Dunn
#
# 01451,25,tenzen,Tenzen,18936,Robert Alexander
#
# 01451,25,megakles,Megakles,729907,B Hall
#
# 01451,25,jcanha,jcanha,6455,Jeff Canha
#
# 01451,25,weirdfishes,WeirdFishes,1301067,Matt Rudmann
#
# 01451,25,anrkist-pengwin,Anrkist Pengwin,84331,Brad Ames
#
# 01451,25,cosmo145,cosmo145,506521,David Salerno
#
# 01451,25,alaska51182,alaska51182,881250,leslie kozloski
#
# 01451,25,bigglesbee,bigglesbee,512263,Brian
#
# 01451,25,amellors23,amellors23,54053,Andrew Mellors
#
# 01451,25,criticalmlss,CriticalMlSS,2242641,Critical MlSS
#
# 01451,25,jlemire1,Jlemire1,881241,Joseph Lemire
#
# 01451,25,hybridtracer,hybridtracer,565665,Egin Tollkuci
#
# 01451,25,roboczar,roboczar,891556,Kevin H
#
# 01451,25,thenotoriousbjg,theNotoriousBJG,314548,Bryan Gregoire
#
# 01451,25,jackanapes70,Jackanapes70,1023679,Greg Campagna
#
# 01451,25,gerafin,gerafin,464833,Michael McDougal
#
# 01451,25,tintros,Tintros,64204,Tim Ryan
#
# 01451,25,nartoff,nartoff,221159,Brett Maguire
#
# 01451,25,phillies,phillies,49655,George Phillies
#
# 01451,25,wpisfs,wpisfs,876042,WPI SFS
#
# 01451,25,adverb,Adverb,320592,Adverb
#
# 2020-03-01 09:14:36, Requests: 1, Users: 454

# %%
np.where(zipcodes=="01451")
# Out:
# (array([277]),)

# %%
zipcodes[278]
# Out:
# '01452'

# %%
data = pd.read_csv(filename)
print(len(data.index))
# Out:
# 33099

# %%
print(len(data.query("population > 8000").index))
# Out:
# 10802

# %%
data.query("zip == '00926'")
# Out:
#      zip      lat       lng      city state_id   state_name  zcta  \
# 105  926  18.3462 -66.05234  San Juan       PR  Puerto Rico  True
#
#      parent_zcta  population  density  county_fips county_name  \
# 105          NaN       96530   1739.6        72127    San Juan
#
#                                  county_weights  \
# 105  {'72061':0.39,'72127':88.13,'72139':11.47}
#
#                     county_names_all    county_fips_all  imprecise  military  \
# 105  San Juan|Trujillo Alto|Guaynabo  72127|72139|72061      False     False
#
#                 timezone
# 105  America/Puerto_Rico

# %%
data\
    .sort_values(by="population", ascending=False)\
    .iloc[10802:]\
    .head(20)
# Out:
#          zip       lat        lng           city state_id     state_name  \
# 19612  57717  44.95180 -103.88836  Belle Fourche       SD   South Dakota
# 20300  59725  45.08976 -112.83786         Dillon       MT        Montana
# 2069    7403  41.02127  -74.33188   Bloomingdale       NJ     New Jersey
# 20949  61341  41.34073  -88.69246     Marseilles       IL       Illinois
# 9860   30553  34.44329  -83.08606        Lavonia       GA        Georgia
# 23205  67124  37.63357  -98.77254          Pratt       KS         Kansas
# 13588  42167  36.72410  -85.67361  Tompkinsville       KY       Kentucky
# 9981   30905  33.41474  -82.14267        Augusta       GA        Georgia
# 14431  44681  40.50209  -81.66119     Sugarcreek       OH           Ohio
# 27986  80615  40.54557 -104.64416          Eaton       CO       Colorado
# 7939   25560  38.44401  -81.89792    Scott Depot       WV  West Virginia
# 24264  70555  30.08119  -92.14556        Maurice       LA      Louisiana
# 26171  75789  32.10912  -95.09694          Troup       TX          Texas
# 5273   17059  40.59169  -77.38457    Mifflintown       PA   Pennsylvania
# 14319  44405  41.07770  -80.59189       Campbell       OH           Ohio
# 30063  90211  34.06496 -118.38294  Beverly Hills       CA     California
# 24279  70584  30.38842  -92.10134         Sunset       LA      Louisiana
# 11139  34431  29.13922  -82.53278      Dunnellon       FL        Florida
# 21245  61951  39.59393  -88.58679       Sullivan       IL       Illinois
# 237     1267  42.67197  -73.23904   Williamstown       MA  Massachusetts
#
#        zcta  parent_zcta  population  density  county_fips  county_name  \
# 19612  True          NaN        8000      2.5        46019        Butte
# 20300  True          NaN        7999      1.4        30001   Beaverhead
# 2069   True          NaN        7999    460.1        34031      Passaic
# 20949  True          NaN        7999     35.0        17099      LaSalle
# 9860   True          NaN        7994     47.1        13119     Franklin
# 23205  True          NaN        7993     11.5        20151        Pratt
# 13588  True          NaN        7992     15.2        21171       Monroe
# 9981   True          NaN        7991    247.2        13245     Richmond
# 14431  True          NaN        7987     50.7        39157   Tuscarawas
# 27986  True          NaN        7982     27.4         8123         Weld
# 7939   True          NaN        7979    132.9        54079       Putnam
# 24264  True          NaN        7974     57.5        22113    Vermilion
# 26171  True          NaN        7972     15.5        48423        Smith
# 5273   True          NaN        7972     35.6        42067      Juniata
# 14319  True          NaN        7969    903.3        39099     Mahoning
# 30063  True          NaN        7969   4649.4         6037  Los Angeles
# 24279  True          NaN        7968     80.1        22097   St. Landry
# 11139  True          NaN        7958     27.6        12083       Marion
# 21245  True          NaN        7956     23.0        17139     Moultrie
# 237    True          NaN        7955     56.6        25003    Berkshire
#
#                                           county_weights  \
# 19612  {'46019':98.5,'46063':0.24,'46081':0.39,'56011...
# 20300                       {'30001':99.95,'30057':0.05}
# 2069                                       {'34031':100}
# 20949                                      {'17099':100}
# 9860                       {'13119':74.03,'13147':25.97}
# 23205                                      {'20151':100}
# 13588                       {'21057':0.14,'21171':99.86}
# 9981                                       {'13245':100}
# 14431                        {'39075':38.4,'39157':61.6}
# 27986                                      {'08123':100}
# 7939                                       {'54079':100}
# 24264                       {'22055':3.64,'22113':96.36}
# 26171         {'48073':37.11,'48401':0.67,'48423':62.22}
# 5273                                       {'42067':100}
# 14319                                      {'39099':100}
# 30063                                      {'06037':100}
# 24279                                      {'22097':100}
# 11139                       {'12075':9.02,'12083':90.98}
# 21245                       {'17029':0.37,'17139':99.63}
# 237                                        {'25003':100}
#
#                    county_names_all          county_fips_all  imprecise  \
# 19612  Butte|Crook|Lawrence|Harding  46019|56011|46081|46063      False
# 20300            Beaverhead|Madison              30001|30057      False
# 2069                        Passaic                    34031      False
# 20949                       LaSalle                    17099      False
# 9860                  Franklin|Hart              13119|13147      False
# 23205                         Pratt                    20151      False
# 13588             Monroe|Cumberland              21171|21057      False
# 9981                       Richmond                    13245      False
# 14431             Tuscarawas|Holmes              39157|39075      False
# 27986                          Weld                    08123      False
# 7939                         Putnam                    54079      False
# 24264           Vermilion|Lafayette              22113|22055      False
# 26171           Smith|Cherokee|Rusk        48423|48073|48401      False
# 5273                        Juniata                    42067      False
# 14319                      Mahoning                    39099      False
# 30063                   Los Angeles                    06037      False
# 24279                    St. Landry                    22097      False
# 11139                   Marion|Levy              12083|12075      False
# 21245                Moultrie|Coles              17139|17029      False
# 237                       Berkshire                    25003      False
#
#        military             timezone
# 19612     False       America/Denver
# 20300     False       America/Denver
# 2069      False     America/New_York
# 20949     False      America/Chicago
# 9860      False     America/New_York
# 23205     False      America/Chicago
# 13588     False      America/Chicago
# 9981      False     America/New_York
# 14431     False     America/New_York
# 27986     False       America/Denver
# 7939      False     America/New_York
# 24264     False      America/Chicago
# 26171     False      America/Chicago
# 5273      False     America/New_York
# 14319     False     America/New_York
# 30063     False  America/Los_Angeles
# 24279     False      America/Chicago
# 11139     False     America/New_York
# 21245     False      America/Chicago
# 237       False     America/New_York

# %%
data.population.plot.hist()
